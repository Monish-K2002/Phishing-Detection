# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_csv("dataset.csv")
data.head()
# Out:
#                                                  url Class
# 0                  http://m.dappsconnectify.com/sync   bad
# 1                     https://www.esepso.caeord.com/   bad
# 2  https://ciei.in/HOST/tnts/jpMixedFixed?uid=aaa...   bad
# 3  https://ciei.in/HOST/tnts/jpMixedFixed/?uid=aa...   bad
# 4                      https://www.epees.caeord.com/   bad

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10951 entries, 0 to 10950
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     10951 non-null  object
#  1   Class   10951 non-null  object
# dtypes: object(2)
# memory usage: 171.2+ KB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
def makeToken(f):
    tkns_BySlash = str(f.encode("utf-8")).split("/")
    total_tokens = []
    for i in tkns_BySlash:
        tokens = str(i).split("-")
        tkns_ByDot = []
        for j in range(0, len(tokens)):
            temp_tokens = str(tokens[j]).split(".")
            tkns_ByDot = tkns_ByDot + temp_tokens
        total_tokens = total_tokens + tokens + tkns_ByDot
    total_tokens = list(set(total_tokens))
    if "com" in toal_tokens:
        total_tokens.remove("com")
    return total_tokens

# %%
y = data["Class"]

# %%
y
# Out:
# 0         bad
# 1         bad
# 2         bad
# 3         bad
# 4         bad
#          ...
# 10946    good
# 10947    good
# 10948    good
# 10949    good
# 10950    good
# Name: Class, Length: 10951, dtype: object

# %%
url_list = data["url"]

# %%
url_list
# Out:
# 0                        http://m.dappsconnectify.com/sync
# 1                           https://www.esepso.caeord.com/
# 2        https://ciei.in/HOST/tnts/jpMixedFixed?uid=aaa...
# 3        https://ciei.in/HOST/tnts/jpMixedFixed/?uid=aa...
# 4                            https://www.epees.caeord.com/
#                                ...
# 10946    paypal.com.loging-confirm.cgi-bin.webscr-cmd.l...
# 10947    paypal.com.us.cgi.bin.webscr.cmd.login.member....
# 10948    paypal.com.us.cgi.bin.webscr.cmd.login.member....
# 10949    rehabstudents.com/wp-content/themes/rsv3/ads/i...
# 10950    www.fazendoweb.net76.net/phpform/use/Form/form...
# Name: url, Length: 10951, dtype: object

# %%
vectorizer = TfidfVectorizer(tokenizer=makeToken)

# %%
url = vectorizer.fit_transform(url_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-05543bddea59> in <module>
# ----> 1 url = vectorizer.fit_transform(url_list)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1839         """
#    1840         self._check_params()
# -> 1841         X = super().fit_transform(raw_documents)
#    1842         self._tfidf.fit(X)
#    1843         # X is already a transformed view of raw_documents so
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1196         max_features = self.max_features
#    1197
# -> 1198         vocabulary, X = self._count_vocab(raw_documents,
#    1199                                           self.fixed_vocabulary_)
#    1200
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1108         for doc in raw_documents:
#    1109             feature_counter = {}
# -> 1110             for feature in analyze(doc):
#    1111                 try:
#    1112                     feature_idx = vocabulary[feature]
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
# --> 106             doc = tokenizer(doc)
#     107         if ngrams is not None:
#     108             if stop_words is not None:
#
# <ipython-input-53-efff6ae38d67> in makeToken(f)
#       9             tkns_ByDot = tkns_ByDot + temp_tokens
#      10         total_tokens = total_tokens + tokens + tkns_ByDot
# ---> 11     total_tokens = list(set(total_tokens))
#      12     if "com" in toal_tokens:
#      13         total_tokens.remove("com")
#
# TypeError: 'Series' object is not callable
